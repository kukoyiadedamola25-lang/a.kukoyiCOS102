# %% [markdown]
# PRINT Select Equation Type: 1.Cubic 2. Quartic 3. Quadratic
# INPUT Choice
# IF Choice == 1 (Cubic):
# INPUT a,b,c,d
# COMPUTE roots using coefficients [a,b,c,d]
# ELSE IF Choice == 2 (Quartic)
# INPUT a,b,c,d,e
# COMPUTE roots using coefficients [a,b,c,d,e]
# ELSE IF Choice == 3 (Quadratic)
# INPUT a,b,c
# COMPUTE roots using coefficients [a,b,c]
# PRINT roots
# END

# %%
# MISSION: EQUATION ROOT FINDER

print("--- MISSION START ---")
print("1. Cubic (Ax**3 + Bx**2 + Cx + D = 0)")
print("2. Quartic (Ax**4 + Bx**3 + Cx**2 + Dx + E = 0)")
print("3. Quadratic (Ax**2 + Bx + C = 0)")

choice = input("\nSelect Mission (1, 2, or 3): ")

if choice == "1":
    a = float(input("Enter A: "))
    b = float(input("Enter B: "))
    c = float(input("Enter C: "))
    d = float(input("Enter D: "))
    print(f"Algorithm set for: {a}x**3 + {b}x**2 + {c}x + {d} = 0")

elif choice == "2":
    a = float(input("Enter A: "))
    b = float(input("Enter B: "))
    c = float(input("Enter C: "))
    d = float(input("Enter D: "))
    e = float(input("Enter E: "))
    print(f"Algorithm set for: {a}x**4 + {b}x**3 + {c}x**2 + {d}x + {e} = 0")

elif choice == "3":
    print("\nSolving Quadratic...")
    a = float(input("Enter A: "))
    b = float(input("Enter B: "))
    c = float(input("Enter C: "))

    discriminant = (b**2) - (4*a*c)

    if discriminant >= 0:
        root1 = (-b + (discriminant**0.5)) / (2*a)
        root2 = (-b - (discriminant**0.5)) / (2*a)
        print(f"Root 1: {root1}")
        print(f"Root 2: {root2}")
    else:
        print("Complex roots detected. Mission requires imaginary numbers.")
