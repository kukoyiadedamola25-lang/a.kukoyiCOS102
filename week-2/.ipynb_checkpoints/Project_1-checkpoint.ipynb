# %% [markdown]
# INPUT Item
# INPUT Price
# INPUT Quantity
# COMPUTE Total_Amount= Price*Quantity
# PRINT Total_Amount
# INPUT Payment_Method
# IF Payment_Method=="Cash"
# INPUT Amount_Paid
# COMPUTE Change= Amount_Paid - Total_Amount
# PRINT Change
# ELSE
# COMPUTE Transaction
# PRINT Payment Confirmation
# ENDIF
# PRINT Receipt
# COMPUTE Inventory - Purchased_Items
# ![Screenshot 2026-03-13 220938.png](attachment:f08ce326-cd0f-4cc3-86bf-f3448dad5cde.png)

# %% [markdown]
# ![Screenshot 2026-03-13 221141.png](attachment:4f6b7ccb-72ac-442a-8d30-aca02d10872c.png)

# %% [markdown]
# ### Task C: Age Swap Algorithm
#
# INPUT name_1
# INPUT age_1
# INPUT name_2
# INPUT age_2
#
# COMPUTE temp_age = age_1
# COMPUTE age_1 = age_2
# COMPUTE age_2 = temp_age
#
# PRINT name_1, age_1
# PRINT name_2, age_2
